# %%
#W2A1
print("hello world")
# Out:
# hello world

# %%
#w2a2
input("tên người")
# Out:
# tên ngườiNguyễn Đình Phong Vân
# 'Nguyễn Đình Phong Vân'

# %%
#w2a3
a=int(input("nhập số thứ nhất :"))
b=int(input("nhập số thứ hai :"))
c=a+b
d=a-b
f=a*b
e=a//b
g=a%b
h=a//b
w=round(h,2)
print(c,d,f,e,g,h,w)
# Out:
# nhập số thứ nhất :7
# nhập số thứ hai :3
# 10 4 21 2 1 2 2

# %%
#w2a4
scores=list(map(float,input().replace(',', '.').split()))
if len(scores)==6:
  a1,b1,c1,a2,b2,a3=scores
  tb=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
  print(f"{tb:.1f}")
else:
  print("Lỗi: Đầu vào phải có 6 số.")
  print("Lỗi: Các số phải là số nguyên hoặc số thực.")
# Out:
# 2.3 2.2 3 4 5 6
# 4.3

# %%
#w2a5
a=int(input("nhập số thứ nhất :"))
b=int(input("nhập số thứ hai :"))
e=a**b
print(e)
# Out:
# nhập số thứ nhất :2
# nhập số thứ hai :5
# 32

# %%
#w2a6
ki_tu='y'
ma_unicode=ord(ki_tu)
ma_unicode_hoa=ma_unicode-32
ki_tu_hoa=chr(ma_unicode_hoa)
print(f"Kí tự thường: '{ki_tu}'")
print(f"Mã Unicode của '{ki_tu}' là: {ma_unicode}")
print(f"Kí tự hoa tương ứng là: '{ki_tu_hoa}'")
# Out:
# Kí tự thường: 'y'
# Mã Unicode của 'y' là: 121
# Kí tự hoa tương ứng là: 'Y'

# %%
#W2a7
a=int(input("nhap so thu nhat"))
b=int(input("nhap so thu hai"))
c=int(input("nhap so thu ba"))
d=int(input("nhap so thu tu"))
A=((a**b)*c)+d
B=a**b*c+d
print(A,B)
# Out:
# nhap so thu nhat13
# nhap so thu hai2
# nhap so thu ba3
# nhap so thu tu5
# 512 512

# %%
#W2a8
C=float(input("nhap so thu nhat"))
print("loi:dau vao la mot so thuc.")
F=1.8*C+32
F=round(F,2)
print(F)
# Out:
# nhap so thu nhat27.8
# loi:dau vao la mot so thuc.
# 82.04

# %%
#w2a9
t=float(input("nhap so thu nhat"))
print("loi:dau vao la mot so thuc.")
T=t*(1+0.3+0.1)+10
T=round(T,2)
print(T)
# Out:
# nhap so thu nhat99
# loi:dau vao la mot so thuc.
# 148.6

# %%
#w2a10
ten_goc=input("nhap ten cua ba nguoi ban (cach nhau bang dau cach):")
danh_sach_ten=ten_goc.split()
if len(danh_sach_ten) != 3:
  print("loi:vui long nhap du ba ten.")
else:
  danh_sach_ten_dao_nguoc=danh_sach_ten[::-1]
  ten_dau_tien=danh_sach_ten_dao_nguoc[0]
  ten_giua=danh_sach_ten_dao_nguoc[1]
  ten_cuoi=danh_sach_ten_dao_nguoc[2]
  print(f"Hi {ten_dau_tien}, {ten_giua} and {ten_cuoi}.")
# Out:
# nhap ten cua ba nguoi ban (cach nhau bang dau cach):v x t
# Hi t, x and v.

# %%
#w2a11
h=int(input("nhap so thu nhat"))
m=int(input("nhap so thu hai"))
print("loi:dau vao la mot so nguyen.")
S=h*3600+m*60
print(S)
# Out:
# nhap so thu nhat3
# nhap so thu hai70
# loi:dau vao la mot so nguyen.
# 15000

# %%
#W2a18
print("""###   ##  ### ###\n #    # #  #   #\n #    # #  #   #\n #    # #  #   #\n #    ##   #   #""")
# Out:
# ###   ##  ### ###
#  #    # #  #   #
#  #    # #  #   #
#  #    # #  #   #
#  #    ##   #   #

# %%
#w2a12
n=int(input("nhap so thu nhat"))
print("loi:dau vao la mot so nguyen duong")
tong_so_mieng_dan=n**2*6
print(tong_so_mieng_dan)
# Out:
# nhap so thu nhat3
# loi:dau vao la mot so nguyen duong
# 54

# %%
#w2a13
a=int(input("nhap so thu nhat"))
b=int(input("nhap so thu hai"))
print("loi:dau vao a va b la so nguyen duong")
h=a*b
hang_don_vi=h%10
print(hang_don_vi)
# Out:
# nhap so thu nhat98
# nhap so thu hai99
# loi:dau vao a va b la so nguyen duong
# 2

# %%
#w2a14
a = 10
b = 20
print(f"Trước khi hoán đổi: a = {a}, b = {b}")
b, a = a, b
print(f"Sau khi hoán đổi: a = {a}, b = {b}")
# Out:
# Trước khi hoán đổi: a = 10, b = 20
# Sau khi hoán đổi: a = 20, b = 10

# %%
#w2a15
n=int(input("nhap so thu nhat"))
print("loi:dau vao la mot so nguyen duong")
so_sao=6*n**2-6*n+1
print(so_sao)
# Out:
# nhap so thu nhat2
# loi:dau vao la mot so nguyen duong
# 13

# %%
#w2a16
print("spring\nsummer\nAutumn\nwinter")
# Out:
# spring
# summer
# Autumn
# winter

# %%
#w2a17
print("""*\n***\n*****""")
# Out:
# *
# ***
# *****

# %%
#w2a19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#w2a20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugus\nSeptember\nOctobe\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# Augus
# September
# Octobe
# November
# December

# %%
#w2a21
for i in range (10):
  print("hello world")
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
